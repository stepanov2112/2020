# %% [markdown]
# <center>Московский Авиационный Институт</center>
# <center>(Национальный Исследовательский Университет)</center>
# <br>
# <br>
# <br>
# <center>Кафедра: 806 «Вычислительная математика и программирование»</center>
# <center>Институт: «Информационные технологии и прикладная математика»</center>
# <center>Дисциплина: «Разработка ПО для высокопроизводительных систем»</center>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <center>Лабораторная работа №7.</center>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <div style="text-align: right"> Группа М80-103М-20 </div>
# <div style="text-align: right"> Студент Степанов Тимур Петрович </div>
# <div style="text-align: right"> Поповкин А.В. </div>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <center>Москва</center>
# <center>2020</center>
# <hr>

# %% [markdown]
# # Лабраторная работа №4 (Pandas)

# %%
import sys
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

titanic = 'https://raw.githubusercontent.com/Grossmend/CSV/master/titanic/data.csv'

# %% [markdown]
# Прочитать файл CSV и перевести его в DataFrame
# 'https://raw.githubusercontent.com/Grossmend/CSV/master/titanic/data.csv'

# %%
ans1 = pd.read_csv(titanic)
ans1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#  Прочитать файл CSV (определенные столбцы и определенное кол-во строк) и перевести его в DataFrame
#  'Name', 'Sex', 'Survived

# %%
ans2 = pd.read_csv(titanic, nrows = 15, usecols=['Name', 'Sex', 'Survived'])
ans2
# Out:
#     Survived                                               Name     Sex
# 0          0                            Braund, Mr. Owen Harris    male
# 1          1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2          1                             Heikkinen, Miss. Laina  female
# 3          1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4          0                           Allen, Mr. William Henry    male
# 5          0                                   Moran, Mr. James    male
# 6          0                            McCarthy, Mr. Timothy J    male
# 7          0                     Palsson, Master. Gosta Leonard    male
# 8          1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9          1                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10         1                    Sandstrom, Miss. Marguerite Rut  female
# 11         1                           Bonnell, Miss. Elizabeth  female
# ...

# %% [markdown]
#  Прочитать файл CSV и перевести каждую 100-ую строку в DataFrame

# %%
ans3 = pd.read_csv(titanic, skiprows = lambda x: x % 100 != 0)
ans3
# Out:
#    PassengerId  Survived  Pclass  \
# 0          100         0       2
# 1          200         0       2
# 2          300         1       1
# 3          400         1       2
# 4          500         0       3
# 5          600         1       1
# 6          700         0       3
# 7          800         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                                  Kantor, Mr. Sinai    male   34      1
# 1             Yrois, Miss. Henriette ("Mrs Harbeck")  female   24      0
# 2    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female   50      0
# 3                   Trout, Mrs. William H (Jessie L)  female   28      0
# 4                                 Svensson, Mr. Olof    male   24      0
# 5       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")    male   49      1
# 6           Humblen, Mr. Adolf Mathias Nicolai Olsen    male   42      0
# 7  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female   30      1
#
# ...

# %% [markdown]
#  Преобразовать индексы объекта Series в столбец DataFrame

# %%
s = pd.Series(np.arange(5), index = ['A', 'B', 'C', 'D', 'E'])
print(s)
df = s.reset_index()
df.columns = ['s.index', 's.values']
df
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# dtype: int32
#   s.index  s.values
# 0       A         0
# 1       B         1
# 2       C         2
# 3       D         3
# 4       E         4

# %% [markdown]
#  Посмотреть информацию объекта DataFrame

# %%
ans1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   s.index   5 non-null      object
#  1   s.values  5 non-null      int32
# dtypes: int32(1), object(1)
# memory usage: 188.0+ bytes

# %% [markdown]
#  Вывести формат каждого столбца

# %%
ans1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Вывести размерность DataFrame

# %%
ans1.shape
# Out:
# (891, 12)

# %% [markdown]
#  Вывести общую статистика

# %%
ans1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
